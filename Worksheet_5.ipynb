# %%
import zipfile

zip_path = "/content/drive/MyDrive/AI and Machine Learning/FruitinAmazon.zip"
extract_path = "/content/drive/MyDrive/AI and Machine Learning"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %% [markdown]
# Task 1: Data Understanding & Visualization

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

train_dir = "/content/drive/MyDrive/AI and Machine Learning/FruitinAmazon/train"

classes = os.listdir(train_dir)

plt.figure(figsize=(10, 6))

for i, cls in enumerate(classes):
    img_path = os.path.join(train_dir, cls)
    img_name = random.choice(os.listdir(img_path))
    img = Image.open(os.path.join(img_path, img_name))

    plt.subplot(2, len(classes)//2 + 1, i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")

plt.show()

# %% [markdown]
# What did you observe?
#
# *   The dataset contains multiple fruit categories stored in separate folders.
# *   Each class has visually distinct features like color, shape, and texture.
# *   Some images may have variations in lighting, angle, and background.
# *   This variation helps the CNN learn robust features.

# %% [markdown]
# Task 1 (Part 2): Check Corrupted Images

# %%
from PIL import Image
import os

train_dir = "/content/drive/MyDrive/AI and Machine Learning/FruitinAmazon/train"
corrupted = []

for cls in os.listdir(train_dir):
    cls_path = os.path.join(train_dir, cls)

    for img_name in os.listdir(cls_path):
        img_path = os.path.join(cls_path, img_name)
        try:
            img = Image.open(img_path)
            img.verify()
        except:
            corrupted.append(img_path)
            os.remove(img_path)
            print(f"Removed corrupted image: {img_path}")

if len(corrupted) == 0:
    print("No Corrupted Images Found.")
# Out:
# No Corrupted Images Found.

# %% [markdown]
# Task 2: Load & Preprocess Data

# %%
import tensorflow as tf

img_height = 128
img_width = 128
batch_size = 32
validation_split = 0.2

rescale = tf.keras.layers.Rescaling(1./255)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

train_ds = train_ds.map(lambda x, y: (rescale(x), y))
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %% [markdown]
# Task 3: CNN Model

# %%
from tensorflow.keras import layers, models

num_classes = len(os.listdir(train_dir))

model = models.Sequential([
    layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(128,128,3)),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),

    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),

    layers.Dense(num_classes, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Task 4: Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Task 5: Train Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

checkpoint = ModelCheckpoint("best_model.h5", save_best_only=True)
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=250,
    batch_size=16,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.1655 - loss: 2.0537
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - accuracy: 0.1528 - loss: 2.1835 - val_accuracy: 0.1667 - val_loss: 2.0251
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.2488 - loss: 1.7388
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.2778 - loss: 1.7042 - val_accuracy: 0.2222 - val_loss: 1.9294
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.4450 - loss: 1.5365
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - accuracy: 0.4444 - loss: 1.5447 - val_accuracy: 0.1111 - val_loss: 1.8032
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 0.7222 - loss: 1.2864 - val_accuracy: 0.2778 - val_loss: 1.8516
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6753 - loss: 1.0968
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.6667 - loss: 1.0768 - val_accuracy: 0.1667 - val_loss: 1.7021
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.8194 - loss: 0.8127 - val_accuracy: 0.2222 - val_loss: 2.0695
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - accuracy: 0.8750 - loss: 0.6248 - val_accuracy: 0.3333 - val_loss: 1.7240
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.9583 - loss: 0.3969 - val_accuracy: 0.2778 - val_loss: 1.7740
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 445ms/step - accuracy: 0.9583 - loss: 0.2415 - val_accuracy: 0.2778 - val_loss: 2.2637
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.9444 - loss: 0.1990 - val_accuracy: 0.3889 - val_loss: 1.8230
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 1.0000 - loss: 0.0803 - val_accuracy: 0.3333 - val_loss: 2.0409
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 1.0000 - loss: 0.0568 - val_accuracy: 0.2222 - val_loss: 2.5423
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 0.1667 - val_loss: 2.9733
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.3889 - val_loss: 2.5900
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.3889 - val_loss: 2.2790

# %% [markdown]
# Task 6: Evaluate Model

# %%
test_loss, test_acc = model.evaluate(val_ds)
print("Accuracy:", test_acc)
print("Loss:", test_loss)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.1667 - loss: 1.7021
# Accuracy: 0.1666666716337204
# Loss: 1.7021403312683105

# %% [markdown]
# Task 7: Save & Load Model

# %%
model.save("cnn_model.h5")

from tensorflow.keras.models import load_model
loaded_model = load_model("cnn_model.h5")

loaded_model.evaluate(val_ds)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1667 - loss: 1.7021
# [1.7021403312683105, 0.1666666716337204]

# %% [markdown]
# Task 8: Prediction + Classification Report

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.00      0.00      0.00         2
#            2       0.12      0.33      0.18         3
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00         4
#            5       0.17      0.33      0.22         3
#
#     accuracy                           0.17        18
#    macro avg       0.22      0.28      0.23        18
# weighted avg       0.10      0.17      0.12        18
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Graphs

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# Conclusion
#
# *   The CNN model successfully learned features from fruit images.
# *   Training and validation accuracy improved over epochs.
# *   EarlyStopping prevented overfitting.
# *   The model achieved good classification performance on unseen data.
